# %% [markdown]
# # Scenario A: Fintech KYC Verification Pipeline
#
# Run this notebook top-to-bottom to regenerate scenario outputs.

# %%
from run_analysis import run_all
artifacts = run_all(selected='kyc')
artifacts['summary_tables'][0].head()
